# %% [markdown]
# ## Normal/Gaussian Distribution in Statistics

# %% [markdown]
# It is a bell shapped curve with continuous probability distribution where most data points cluster around the mean, and the probabilities decrease symmentrically as you move away from the center.

# %% [markdown]
# ![Screenshot 2024-11-09 at 2.28.00 PM.png](attachment:ad34b3d4-1857-4351-a547-c1dade40e895.png)

# %% [markdown]
# ### Why Normal Distribution is important?
#
# Data can be "Distributed" (spread out) in different ways.
#
# It can be spread out:
#
# **more on the left or more on the right**

# %% [markdown]
# ![Screenshot 2024-11-09 at 2.29.45 PM.png](attachment:0e852e36-3377-456a-8413-822fb638808f.png)

# %% [markdown]
# **Or it can be all random data**

# %% [markdown]
# ![Screenshot 2024-11-09 at 2.30.30 PM.png](attachment:2dbc0422-a1ac-45b3-ac9f-31ce3b025a0c.png)

# %% [markdown]
# But there are many cases where the data trends to be around a central value with no bias left or right, and it gets close to a **"Normal Distribution"** like this

# %% [markdown]
# ![Screenshot 2024-11-09 at 2.31.27 PM.png](attachment:5afcd7b0-f97e-4318-bc6a-5ed57d13518f.png)

# %% [markdown]
# The black curve is called a **Normal Distribution**.
#
# The blue histogram shows some data that closely follows it, but not perfectly (which is usually the case with data).
#
# Many things closely follow a Normal Distribution:
#
# - Weights/heights/blood pressure of people
#
# - Size of things produced by machines
#
# - Pizza delivery time
#
# - Errors in measurements or experimental data
#
# - Stock market returns over a long period of time
#
# - SAT/JEE/GRE scores

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Generate random numbers from the Guassian distribution
num_samples =1000
guassian_data= np.random.normal(loc= 0.5, scale=0.2, size=num_samples)

# %%
# Plot the histogramn of the generated data
plt.figure(figsize=(8,6))
sns.histplot(guassian_data, bins= 30, kde= True, color="orange", alpha=0.7)
plt.title("Histogram of Guassian Distribution")
plt.xlabel("Value")
plt.ylabel("Density")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Common Properties of the Normal Distribution
#
# - **Unimodal and Symmentric:** A normal distribution has a single peak(unimodal) and is symmentric around its mean.
#
# - **Equal Measures of Central Tendency:** The mean, median and mode are all equal in a normal distribution.
#
# - **Spread and Standard Deviation:** The standard deviation measures the spread of data. Roughly half of the population falls below the mean, and the other half lies above it.
#
# - **Asymptotic Tails:** The tails of a normal distribution extend infinitely in both directions, approaching the x-axis.
#
# - **Area Under the Graph:** In a normal distribution, the total area under the graph represents the total probability, and it always sums up to 1 (for every probability density function(PDF))
#
# - **68-95-99.7 Rule:** The empirical rule states that about 68% of the data falls within one standard deviation of the mean, about 95% falls within two standard deviation, and about 99.7% falls within three standard deviations.

# %% [markdown]
# ![Screenshot 2024-11-09 at 2.33.43 PM.png](attachment:8d8aba22-1a67-45d1-bfee-dc5aa6abab8a.png)

# %% [markdown]
# ### Standard Normal Variate/ Standard Normal Distribution(Z)

# %% [markdown]
# It is a standardized form of Normal Distribution, where the mean is zero and the standard deviation is 1. This distribution is also known as the Z-distribution.

# %% [markdown]
# ![Screenshot 2024-11-09 at 2.34.49 PM.png](attachment:3568692a-45f7-4285-98ee-fcf32044426a.png)

# %% [markdown]
# ### Standard Score

# %% [markdown]
# A standard score represents the number of standard deviation above or below the mean that a specific observation falls.
#
# **For example**, a standard score of -2.65 indicates that the observation is 2.65 standard deviation below the mean. On the other hand, a positive score represents a value above the average. The mean has a Z-score of 0.

# %% [markdown]
# ### Why do we need Standard Score?
#
# The standard score/z-score, is a very useful statistic for two main reasons:
#
# - **Probability Caluclation:** It allows us to caluclate the probability of a score occuring within a normal distribution.
#
# - **Comparision Across Distribution:** It enables us to compare two scores that comes from different normal distribution

# %% [markdown]
# **Note:** Standardizing your data before applying machine learning or deep learning models is a recommended practice. It ensures that features are on a common scale, while helps algorithms perform better and coverage faster during training to make robust model and improves its ability to generalize across different datasets.

# %% [markdown]
# ### How to caluclate Z-score?

# %% [markdown]
# Mathematically, to caluclate the z-score of a data point in a normal distribution:

# %% [markdown]
# ![Screenshot 2024-11-09 at 2.37.36 PM.png](attachment:87df8882-ead6-4238-ae64-bf92b1db5950.png)

# %%
#set the mean and standard deviation of the Guassian distribution
mean=0
std_dev=1

# %%
# Generate random numbers from the Guassian distribution
num_samples= 1000
standardized_data= np.random.normal(mean, std_dev, num_samples)

# %%
# Plot the histogram of the generated data
plt.figure(figsize=(8,6))
sns.histplot(standardized_data, bins=30, kde=True, color="orange", alpha=0.7)
plt.title("Histogram of Guassian Distribution")
plt.xlabel("Value")
plt.ylabel("Denisity")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Empirical Rule

# %% [markdown]
# It states that approximately 68% data falls within it states that for a normal distribution:
#
# - Approximately **68%** of the data falls within **one standard deviation() of the mean()**
#
# - Approximately **95%** of the data falls within **two standard deviation() of the mean()**
#
# - Approximately **99.7%** of the data falls within **three standard deviation() of the mean()**

# %% [markdown]
# ![Screenshot 2024-11-09 at 2.38.43 PM.png](attachment:58d4cd5f-d090-48fe-91f2-fb499b8306b2.png)

# %% [markdown]
# ### Use of Normal Distribution in Data Science and ML
#
# - **Statistical Modelling:** Normal distribution is often assumed in statistical modelling due to its simplicity and wide applicability, making it a fundamental concept in regression analysis, hypothesis testing and ANOVA.
#
# - **Feature Engineering:** Identifying and transforming features to follow a normal distribution can improve the performance of linear models and algorithms like linear regression and logistic regression.
#
# - **Outlier Regression:** Normal distribution based methods, such as Z-score or mahalanobis distance, are commonly used for detecting outliers in datasets.
#
# - **Central Limit Theorm:** It forms the basis of the Central Limit Theorem, which states that the sampling distribution of the sample mean approaches a normal distribution as the sample size increases, allowing for the estimation of population parameters.
#
# - **Error Distribution:** In many machine learning algorithms, such as linear regression and Guassian Navie Bayes, the assumption of normally distributed errors is made for accurate parameter estimation and interference.
#
# - **Residual Analysis:** Checking the normality of residuals in assessing the goodness-of-fit of regression models and ensuring the validity of statistical inferences.
#
# - **Anomaly Detection:** Guassian Mixture Models (GMMs) are employed for anomaly detection by modeling normal behavior and identifying deviations from it.
#
# - **Classification:** In Bayesian classifiers like Navie Bayes, normal distribution is assumed for continous features, allowing for efficient and accurate classification.
#
# - **Model Evaluation:** Normality tests, such as Shapiro-Wilk test or Kolmogorov-Smirnov tests, are used to assess the normality of data distributions, which is crucial for selecting appropiate statistical tests and evaluating model assumptions.

# %% [markdown]
# ### How to find if a given distribution is normal or not?

# %% [markdown]
# Here are a few common methods:
#
# - **Visual Inspection:**
#
#   - **Histogram:** A bell-shaped curve with symmentrical data around the mean indicates normality.
#   - **Q-Q Plot:** A straight line suggests normal distribution
#
# - **Statistical Tests:**
#
#   - **Shapiro-Wilk, Anderson-Darling and Kolmogorov-Smirnov** tests compare data to expected normal distribution.
#   - Low p-values(<0.05) indicate non-normality.
#
# - **Summary Statistics:**
#
#   - **Skewness:** Normal distribution has skewness of 0.
#   - **Kurtosis:** Normal distribution has kurtosis of 3.
