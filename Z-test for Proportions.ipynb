# %% [markdown]
# # Z-test for Proportions in statistics

# %% [markdown]
# A Z-test for Proportions is a Statistics hypothesis test used to determine whether the proportion of sucesses in a sample is significantly different from a hypothesized population proportion.
#
# **Note:** It is particularly used when dealing with categorical data and binary outcomes.

# %% [markdown]
# ### Why Use a Z-test for Proportions?

# %% [markdown]
# When we want to proportions (like the percentage of people who prefer one brand over another), we often use a statistical test. There are two common tests: the Z-test and t-test.
#
# The Z-test is like a shortcut that's really handy when we have a lot of data. It helps us figure out if there's a meaningful difference between proportions. We use it when we know or have a good guess about the standard deviation of the difference between proportions.
#
# But sometimes, people use the t-test instead, even though it's not technically the right tool for the job. The t-test is meant for comparing averages, not proportions. However, wehen we have a lot of data, the results from a t-test end up looking pretty similiar to what we'd get from a Z-test.
#
# So, while the t-test isn't the best choice for proportions, it can still give us useful information, especially when we have a big bunch of data to work with.

# %% [markdown]
# ![image.png](attachment:0bb43dee-154e-4970-9524-b6c55d69df38.png)

# %% [markdown]
# ![image.png](attachment:2040b6c0-172e-4aa9-87c5-c3caea01f8f0.png)

# %% [markdown]
# **A two proportion Z-test is conducted on two proportions to check if they are the same or not.**

# %% [markdown]
# ### Question:

# %% [markdown]
# A company wants to improve the quality of products by reducing defects and monitoring the efficiency of assembly lines. In assembly line A, there were 18 defects reported out of 200 samples while in line B, 25 defects out of 600 samples were noted. Is there a difference in the procedures at a 0.05 alpha level?

# %% [markdown]
# ### Formulate Hypotheses:

# %% [markdown]
# - Null Hypothesis (HO): There is no difference in the defect rates between assembly lines A and B (𝑝𝐴 = 𝑝𝐵).
# - Alternative Hypothesis (H1): There is a difference in the defect rates between assembly lines A and B (𝑝𝐴 ≠ 𝑝𝐵).

# %% [markdown]
# ### Method 1: Using standard formula library

# %%
import numpy as np
from scipy.stats import norm

# %%
# Sample sizes and defect counts for assembly lines A and B
defects_A= 18
samples_A= 200
defects_B= 25
samples_B= 600

# %%
# Calculate sample proportions
p_hat_A= defects_A/ samples_A
p_hat_B= defects_B/ samples_B

# Calculate pooled sample proportion
p_hat_pooled= (defects_A + defects_B)/ (samples_A + samples_B)

# Caluclate standard error
SE= np.sqrt(p_hat_pooled * (1- p_hat_pooled) * (1/samples_A + 1/samples_B))
print(SE)
# Out:
# 0.018413932677911766

# %%
# Calculate test statistic
Z= (p_hat_A - p_hat_B)/SE

print("Test statitic:", Z)
print("P-value:", 2 *(1-norm.cdf(np.abs(Z))))

# Two-tailed test, so multiply alpha by 2
alpha= 0.05
alpha*= 2

# Determine critical value
critical_value= norm.ppf(1- alpha/2)
print("Critical_Value:", critical_value)
# Out:
# Test statitic: 2.624824049200042
# P-value: 0.008669375420073067
# Critical_Value: 1.6448536269514722

# %% [markdown]
# As 2.62 > 1.64 thus, the null hypothesis is rejected and it is concluded that there is a significant difference between the two lines.

# %%
# Make decision
if np.abs(Z)> critical_value:
    print("Reject the null hypothesis: There is a significant difference in defect rates between assembly lines A and B.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference in defect rates between assembly lines A and B.")
# Out:
# Reject the null hypothesis: There is a significant difference in defect rates between assembly lines A and B.

# %% [markdown]
# -- This code calculates the test statistics (Z) and compares it with the critical value for a two-tailed test at a significance level of 0.0.5.
#
# > If the absolute value of the test statistic exceeds the critical value, we reject the null hypothesis and conclude that there is a significant difference in defect rates between assembly lines A and B.
#
# > Otherwise, we fail to reject the null hypothesis.

# %% [markdown]
# ![image.png](attachment:da07eef6-5443-41cd-a0f3-18b449702788.png)

# %%
# Calculate confidence interval for the difference in proportions
margin_of_error = critical_value * SE
confidence_interval = (p_hat_A - p_hat_B - margin_of_error, p_hat_A - p_hat_B + margin_of_error)
print("Confidence Interval for the Difference in Proportions:", confidence_interval)
# Out:
# Confidence Interval for the Difference in Proportions: (0.01804510938162993, 0.07862155728503674)

# %% [markdown]
# ### Method 2: Using Statsmodels library

# %%
from statsmodels.stats.proportion import proportions_ztest

# %%
# Perform z-test for proportions

# Counts of sucesses (defects) in the two samples
successes = np.array([defects_A, defects_B])

# Sample sizes of the two samples
sample_sizes = np.array([samples_A, samples_B])

# Performs two-sample z-test for proportions
stats, p_value = proportions_ztest(successes, sample_sizes, alternative= 'two-sided')

# Print the test statistics and p-value
print("Test Statistic:", stats)
print("P-value:", p_value)

# Set significance level (alpha)
alpha= 0.05

# Compare p-value with alpha
if p_value< alpha:
    print("Reject the null hypothesis: There is a significant difference in defect rates between assembly lines A and B.")
else:
    print("Fail to reject the null hypothesis: There is no significant difference in defect rates between assembly lines A and B.")

print(f"P-value: {p_value:.3f}")
# Out:
# Test Statistic: 2.624824049200042
# P-value: 0.008669375420073044
# Reject the null hypothesis: There is a significant difference in defect rates between assembly lines A and B.
# P-value: 0.009

# %% [markdown]
# -- This code performs a two-sample z-test for proportions using the proportions_ztest function from the statsmodel library.
#
# It then compares the obtained p-value with the significance level (alpha) to significant make a decision regarding the null hypothesis.
#
# - If the p-value is less than alpha, the null hypothesis is rejected, indicating a significant difference in defect rates between assembly line A and B.
#
# - Otherwise, the null hypothesis is not rejected.

# %% [markdown]
# ### Two-Proportion Z-test:

# %% [markdown]
# **Advantages:**
#
# - Allows for comparing two proportion from independent samples, making it suitable for evaluating difference two groups. Situable for large sample sizes, ensuring reliable results and robustness.
#
# **Disadvantages:**
#
# - Assumes that the sample proportions follow a normal distribution, which may not hold true for small samples sizes or when the population proportions are close to 0 to 1.
# - Requires independence between samples and random sampling to ensure validity of results. Limited to comparisons involving multiple groups or factors.

# %% [markdown]
# ![image.png](attachment:c7a262f7-9085-4fda-b49f-7be6ee927d49.png)

# %% [markdown]
# ![image.png](attachment:23507b26-152d-48e1-b49a-68ae6539e9ed.png)

# %% [markdown]
# **A one proportion Z test is used when there are two groups and compares the values of an observed proportion to a theoretical one.**
#
# The null hypothesis is that the two proportions are the same while the alternative hypothesis is that they are not the same.

# %% [markdown]
# ### Question:

# %% [markdown]
# Suppose an algorithm for Ad selection is implemented, and we aim to estimate the click-through rate (𝑝) of users on Ads selected by this algorithm. With access to data from 1000 users, the observed click-through rate is p_hat=0.2. We set a significance level of 5%.

# %% [markdown]
# ### Formulate Hypothesis:

# %% [markdown]
# - Null Hypothesis (HO): The click-through rate (𝑝) is equal to 0.15.
# - Alternative Hypothesis (H1): The click-through rate (𝑝) is not equal to 0.15

# %%
# Given data
n= 1000 # Total numbers of users
p_hat= 0.2 # Observed click-through rate
p0= 0.15 # Hypothesized click-through rate (under H0)
alpha= 0.05 # Significance level

# %%
# Calculate the standard error
SE= np.sqrt((p_hat * ((1-p_hat))/n))

# Calculate the z-score
Z= (p_hat - p0)/ SE
print("Test Statistic (Z-score):", Z)
# Out:
# Test Statistic (Z-score): 3.952847075210475

# %%
# Calculate the critical value
critical_value = norm.ppf(1 - alpha/2)
print("Critical Value:", critical_value)

# Calculate the p-value
p_value = 2 * (1 - norm.cdf(np.abs(Z)))
print("P-value:", p_value)

# Make a decision based on the p-value
if p_value < alpha:
    print("Reject the null hypothesis: There is evidence that the click-through rate is different from 0.5.")
else:
    print("Fail to reject the null hypothesis: There is no evidence that the click-through rate is different from 0.5.")
# Out:
# Critical Value: 1.959963984540054
# P-value: 7.72267955053696e-05
# Reject the null hypothesis: There is evidence that the click-through rate is different from 0.5.

# %% [markdown]
# ![image.png](attachment:b1597183-5436-497e-b33d-c418056d9049.png)

# %%
# Calculate confidence interval
margin_of_error = critical_value * SE
lower_bound = p_hat - margin_of_error
upper_bound = p_hat + margin_of_error

print("Confidence Interval: [{:.4f}, {:.4f}]".format(lower_bound, upper_bound))
# Out:
# Confidence Interval: [0.1752, 0.2248]

# %% [markdown]
# ### One-Proportion Z-test:

# %% [markdown]
# **Advantages:**
#
# - Provides a straightforward hypothesis test to determine if the observed proportion significantly differs from a specified value.
# - Applicable to large sample sizes, ensuring robustness and reliability of results.
#
# **Disadvantages:**
#
# - Limited to comparing a single proportion to a specified value, making it less flexible for more complex comparisons.
# - Assumes that the sample proportion follows a normal distribution, which may not always hold true for small sample sizes or when the population proportion is close to 0 or 1.
